# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
crime_anal_police = pd.read_csv('C:\myPyCode\data\crime_in_Seoul.csv', thousands=',', encoding='euc-kr')
crime_anal_police.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861

# %%
# 서울시 지역구 경찰서 목록
police = [서울특별시경찰청
101경비단
202경비단
서울강남경찰서
서울강동경찰서
서울강북경찰서
서울강서경찰서
서울관악경찰서
서울광진경찰서
서울구로경찰서
국회경비대
서울금천경찰서
서울남대문경찰서
서울노원경찰서
서울도봉경찰서
서울동대문경찰서
서울동작경찰서
서울마포경찰서
서울방배경찰서
서울서대문경찰서
서울서부경찰서
서울서초경찰서
서울성동경찰서
서울성북경찰서
서울송파경찰서
서울수서경찰서
서울양천경찰서
서울영등포경찰서
서울용산경찰서
서울은평경찰서
정부서울청사경비대
서울종로경찰서
서울종암경찰서
서울중랑경찰서
서울중부경찰서
서울지하철경찰대
서울혜화경찰서]

# %%
# google api 키 : AIzaSyDiJXlcNbyL9LCpgFhu_cbo31uDsZ15Cqo

# %%
import googlemaps

# %%
gmaps_key = 'AIzaSyDiJXlcNbyL9LCpgFhu_cbo31uDsZ15Cqo'
gmaps = googlemaps.Client(key=gmaps_key)

# %%
gmaps.geocode('서울동작경찰서', language='ko')
# Out:
# [{'address_components': [{'long_name': '１４８',
#     'short_name': '１４８',
#     'types': ['premise']},
#    {'long_name': '노량진로',
#     'short_name': '노량진로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '동작구',
#     'short_name': '동작구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '156-051',
#     'short_name': '156-051',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 동작구 노량진로 148',
#   'geometry': {'location': {'lat': 37.5130866, 'lng': 126.9428498},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5144355802915,
#      'lng': 126.9441987802915},
#     'southwest': {'lat': 37.51173761970851, 'lng': 126.9415008197085}}},
# ...

# %%
station_name= []

for name in crime_anal_police['관서명']:
    station_name.append('서울시 '+str(name[0:-1])+"경찰서")
    
station_name
# Out:
# ['서울시 중부경찰서',
#  '서울시 종로경찰서',
#  '서울시 남대문경찰서',
#  '서울시 서대문경찰서',
#  '서울시 혜화경찰서',
#  '서울시 용산경찰서',
#  '서울시 성북경찰서',
#  '서울시 동대문경찰서',
#  '서울시 마포경찰서',
#  '서울시 영등포경찰서',
#  '서울시 성동경찰서',
#  '서울시 동작경찰서',
#  '서울시 광진경찰서',
#  '서울시 서부경찰서',
#  '서울시 강북경찰서',
#  '서울시 금천경찰서',
#  '서울시 중랑경찰서',
#  '서울시 강남경찰서',
#  '서울시 관악경찰서',
#  '서울시 강서경찰서',
#  '서울시 강동경찰서',
#  '서울시 종암경찰서',
#  '서울시 구로경찰서',
#  '서울시 서초경찰서',
#  '서울시 양천경찰서',
#  '서울시 송파경찰서',
#  '서울시 노원경찰서',
#  '서울시 방배경찰서',
#  '서울시 은평경찰서',
#  '서울시 도봉경찰서',
#  '서울시 수서경찰서']

# %%
station_address = []
station_lat = []
station_lng = []

for name in station_name:
    tmp = gmaps.geocode(name, language='ko')
    station_address.append(tmp[0].get('formatted_address'))
    
    tmp_loc = tmp[0].get('geometry')
    station_lat.append(tmp_loc['location']['lat'])
    station_lng.append(tmp_loc['location']['lng'])
    print(name + "-->" + tmp[0].get('formatted_address'))
# Out:
# 서울시 중부경찰서-->대한민국 서울특별시 중구 수표로 27
# 서울시 종로경찰서-->대한민국 서울특별시 종로구 인사동5길 41
# 서울시 남대문경찰서-->대한민국 서울특별시 중구 한강대로 410
# 서울시 서대문경찰서-->대한민국 서울특별시 서대문구 통일로 113
# 서울시 혜화경찰서-->대한민국 서울특별시 종로구 창경궁로 112-16
# 서울시 용산경찰서-->대한민국 서울특별시 용산구 백범로 329
# 서울시 성북경찰서-->대한민국 서울특별시 성북구 삼선동 보문로 170
# 서울시 동대문경찰서-->대한민국 서울특별시 동대문구 약령시로21길 29
# 서울시 마포경찰서-->대한민국 서울특별시 마포구 마포대로 183
# 서울시 영등포경찰서-->대한민국 서울특별시 영등포구 국회대로 608
# 서울시 성동경찰서-->대한민국 서울특별시 성동구
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [17], line 7
#       5 for name in station_name:
#       6     tmp = gmaps.geocode(name, language='ko')
# ----> 7     station_address.append(tmp[0].get('formatted_address'))
#       9     tmp_loc = tmp[0].get('geometry')
#      10     station_lat.append(tmp_loc['location']['lat'])
#
# IndexError: list index out of range

# %%
station_address
# Out:
# ['대한민국 서울특별시 중구 수표로 27',
#  '대한민국 서울특별시 종로구 인사동5길 41',
#  '대한민국 서울특별시 중구 한강대로 410',
#  '대한민국 서울특별시 서대문구 통일로 113',
#  '대한민국 서울특별시 종로구 창경궁로 112-16',
#  '대한민국 서울특별시 용산구 백범로 329',
#  '대한민국 서울특별시 성북구 삼선동 보문로 170',
#  '대한민국 서울특별시 동대문구 약령시로21길 29',
#  '대한민국 서울특별시 마포구 마포대로 183',
#  '대한민국 서울특별시 영등포구 국회대로 608',
#  '대한민국 서울특별시 성동구']

# %%
station_lat
# Out:
# [37.56361709999999,
#  37.571824,
#  37.5547584,
#  37.5647439,
#  37.5719679,
#  37.5387099,
#  37.58977830000001,
#  37.58506149999999,
#  37.550814,
#  37.5260441,
#  37.5633415]

# %%
station_lng
# Out:
# [126.9896517,
#  126.9841533,
#  126.9734981,
#  126.9667705,
#  126.9989574,
#  126.9659183,
#  127.016589,
#  127.0457679,
#  126.954028,
#  126.9008091,
#  127.0371025]

# %%
gu_name = []

for name in station_address:
    tmp = name.split()
    tmp_gu = [gu for gu in tmp if gu[-1] == '구'][0]
    
    gu_name.append(tmp_gu)
    
crime_anal_police['구별'] = gu_name
crime_anal_police.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [19], line 9
#       5     tmp_gu = [gu for gu in tmp if gu[-1] == '구'][0]
#       7     gu_name.append(tmp_gu)
# ----> 9 crime_anal_police['구별'] = gu_name
#      10 crime_anal_police.head()
#
# File C:\Anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File C:\Anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
# ...

# %%
crime_anal_police.loc[crime_anal_police['관서명']=='도봉서',['구별']]='도봉구'

# %%
crime_anal_police.head(30)
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65   1395    477   1355
# 1    종로서      3      3      6      5    115     98   1070    413   1278
# 2   남대문서      1      0      6      4     65     46   1153    382    869
# 3   서대문서      2      2      5      4    154    124   1812    738   2056
# 4    혜화서      3      2      5      4     96     63   1114    424   1015
# 5    용산서      5      5     14     14    194    173   1557    587   2050
# 6    성북서      2      2      2      1     86     71    953    409   1194
# 7   동대문서      5      5     13     13    173    146   1981    814   2548
# 8    마포서      8      8     14     10    294    247   2555    813   2983
# 9   영등포서     14     12     22     20    295    183   2964    978   3572
# 10   성동서      4      4      9      8    126    119   1607    597   1612
# 11   동작서      5      5      9      5    285    139   1865    661   1910
# ...

# %%
crime_anal_police.to_csv('C:\myPyCode\data\crime_in_Seoul_include_gu_name.csv',sep=",", encoding='utf-8')

# %%
crime_anal_raw = pd.read_csv('C:\myPyCode\data\crime_in_Seoul_include_gu_name.csv', encoding='utf-8')
crime_anal_raw.head()
# Out:
#    Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0           0   중부서      2      2      3      2    105     65   1395    477
# 1           1   종로서      3      3      6      5    115     98   1070    413
# 2           2  남대문서      1      0      6      4     65     46   1153    382
# 3           3  서대문서      2      2      5      4    154    124   1812    738
# 4           4   혜화서      3      2      5      4     96     63   1114    424
#
#    폭력 발생  폭력 검거    구별
# 0   1355   1170    중구
# 1   1278   1070   종로구
# 2    869    794  남대문구
# 3   2056   1711  서대문구
# 4   1015    861   종로구

# %%
crime_anal_raw = pd.read_csv('C:\myPyCode\data\crime_in_Seoul_include_gu_name.csv', encoding='utf-8', index_col=0)
crime_anal = pd.pivot_table(crime_anal_raw, index = '구별', aggfunc=np.sum)
crime_anal.head()
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생
# 구별
# 강남구    225    300     12     15      3      3    984   2411   2146   2465
# 강동구    123    156      8      6      3      4    789   2366   2248   2712
# 강북구    126    153     13     14      8      7    618   1434   2348   2649
# 강서구    191    262     13     13      8      7   1260   2096   2718   3207
# 관악구    221    320     14     12      8      9    827   2706   2642   3298

# %%
crime_anal['강간검거율'] = crime_anal['강간 검거']/crime_anal['강간 발생']*100
crime_anal['강도검거율'] = crime_anal['강도 검거']/crime_anal['강도 발생']*100
crime_anal['살인검거율'] = crime_anal['살인 검거']/crime_anal['살인 발생']*100
crime_anal['절도검거율'] = crime_anal['절도 검거']/crime_anal['절도 발생']*100
crime_anal['폭력검거율'] = crime_anal['폭력 검거']/crime_anal['폭력 발생']*100

# %%
del crime_anal['강간 검거']
del crime_anal['강도 검거']
del crime_anal['살인 검거']
del crime_anal['절도 검거']
del crime_anal['폭력 검거']

# %%
crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구    300     15      3   2411   2465  75.000000   80.000000  100.000000
# 강동구    156      6      4   2366   2712  78.846154  133.333333   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  114.285714
# 강서구    262     13      7   2096   3207  72.900763  100.000000  114.285714
# 관악구    320     12      9   2706   3298  69.062500  116.666667   88.888889
#
#          절도검거율      폭력검거율
# 구별
# 강남구  40.812941  87.058824
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 강서구  60.114504  84.752105
# 관악구  30.561715  80.109157

# %%
con_list = ['강간검거율','강도검거율','절도검거율','살인검거율','폭력검거율']

for column in con_list:
    crime_anal.loc[crime_anal[column] > 100, column] = 100

# %%
crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구    300     15      3   2411   2465  75.000000   80.000000  100.000000
# 강동구    156      6      4   2366   2712  78.846154  100.000000   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  100.000000
# 강서구    262     13      7   2096   3207  72.900763  100.000000  100.000000
# 관악구    320     12      9   2706   3298  69.062500  100.000000   88.888889
#
#          절도검거율      폭력검거율
# 구별
# 강남구  40.812941  87.058824
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 강서구  60.114504  84.752105
# 관악구  30.561715  80.109157

# %%
crime_anal.rename(columns = {'강간 발생':'강간','강도 발생':'강도','살인 발생':'살인','절도 발생':'절도','폭력 발생':'폭력'},
                 inplace = True)

# %%
crime_anal.head()
# Out:
#       강간  강도  살인    절도    폭력      강간검거율       강도검거율       살인검거율      절도검거율  \
# 구별
# 강남구  300  15   3  2411  2465  75.000000   80.000000  100.000000  40.812941
# 강동구  156   6   4  2366  2712  78.846154  100.000000   75.000000  33.347422
# 강북구  153  14   7  1434  2649  82.352941   92.857143  100.000000  43.096234
# 강서구  262  13   7  2096  3207  72.900763  100.000000  100.000000  60.114504
# 관악구  320  12   9  2706  3298  69.062500  100.000000   88.888889  30.561715
#
#          폭력검거율
# 구별
# 강남구  87.058824
# 강동구  82.890855
# 강북구  88.637222
# 강서구  84.752105
# 관악구  80.109157
